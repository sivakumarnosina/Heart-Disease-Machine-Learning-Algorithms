# %% [markdown]
# # **EDA-(Exploratory Data Analysis)**

# %%
#import the required liabraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import missingno as msno

# %%
#Read the dataset from Drive
heart_7 = pd.read_csv('/content/drive/MyDrive/heart rate.csv')
heart_7
# Out:
#      age  sex   cp  trtbps   chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1  3.0   145.0  233.0  1.0      0.0     150.0   0.0      2.3  0.0
# 1     37    1  2.0   130.0  250.0  0.0      1.0     187.0   0.0      3.5  0.0
# 2     41    0  1.0   130.0  204.0  0.0      0.0     172.0   0.0      1.4  2.0
# 3     56    1  1.0   120.0  236.0  0.0      1.0     178.0   0.0      0.8  2.0
# 4     57    0  0.0   120.0  354.0  0.0      1.0     163.0   1.0      0.6  2.0
# ..   ...  ...  ...     ...    ...  ...      ...       ...   ...      ...  ...
# 298   57    0  0.0   140.0  241.0  0.0      1.0     123.0   1.0      0.2  1.0
# 299   45    1  3.0   110.0  264.0  0.0      1.0     132.0   0.0      1.2  1.0
# 300   68    1  0.0   144.0  193.0  1.0      1.0     141.0   0.0      3.4  1.0
# 301   57    1  0.0   130.0  131.0  0.0      1.0     115.0   1.0      1.2  1.0
# 302   57    0  1.0   130.0  236.0  0.0      0.0     174.0   0.0      0.0  1.0
#
#      caa  thall  output
# ...

# %%
#info it shows all unique column
heart_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        275 non-null    float64
#  3   trtbps    260 non-null    float64
#  4   chol      250 non-null    float64
#  5   fbs       260 non-null    float64
#  6   restecg   260 non-null    float64
#  7   thalachh  293 non-null    float64
#  8   exng      281 non-null    float64
#  9   oldpeak   275 non-null    float64
#  10  slp       253 non-null    float64
#  11  caa       253 non-null    float64
#  12  thall     265 non-null    float64
#  13  output    303 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 33.3 KB

# %%
#head
heart_7.head(10)
# Out:
#    age  sex   cp  trtbps   chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1  3.0   145.0  233.0  1.0      0.0     150.0   0.0      2.3  0.0
# 1   37    1  2.0   130.0  250.0  0.0      1.0     187.0   0.0      3.5  0.0
# 2   41    0  1.0   130.0  204.0  0.0      0.0     172.0   0.0      1.4  2.0
# 3   56    1  1.0   120.0  236.0  0.0      1.0     178.0   0.0      0.8  2.0
# 4   57    0  0.0   120.0  354.0  0.0      1.0     163.0   1.0      0.6  2.0
# 5   57    1  0.0   140.0  192.0  0.0      1.0     148.0   0.0      0.4  1.0
# 6   56    0  1.0   140.0  294.0  0.0      0.0     153.0   0.0      1.3  1.0
# 7   44    1  1.0   120.0  263.0  0.0      1.0     173.0   0.0      0.0  2.0
# 8   52    1  2.0   172.0  199.0  1.0      1.0     162.0   0.0      0.5  2.0
# 9   57    1  2.0   150.0    NaN  NaN      NaN       NaN   NaN      NaN  2.0
#
#    caa  thall  output
# 0  0.0    1.0       1
# 1  0.0    2.0       1
# 2  0.0    2.0       1
# 3  0.0    2.0       1
# ...

# %%
heart_7.tail(20)
# Out:
#      age  sex   cp  trtbps   chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 283   40    1  0.0   152.0  223.0  0.0      1.0     181.0   0.0      0.0  2.0
# 284   61    1  0.0   140.0  207.0  0.0      0.0     138.0   1.0      1.9  2.0
# 285   46    1  0.0   140.0  311.0  0.0      1.0     120.0   1.0      1.8  1.0
# 286   59    1  3.0   134.0  204.0  0.0      1.0     162.0   0.0      0.8  2.0
# 287   57    1  1.0   154.0  232.0  0.0      0.0     164.0   0.0      0.0  2.0
# 288   57    1  0.0   110.0  335.0  0.0      1.0     143.0   1.0      3.0  1.0
# 289   55    0  0.0   128.0  205.0  0.0      2.0     130.0   1.0      2.0  1.0
# 290   61    1  0.0   148.0  203.0  0.0      1.0     161.0   0.0      0.0  2.0
# 291   58    1  0.0   114.0  318.0  0.0      2.0     140.0   0.0      4.4  0.0
# 292   58    0  0.0   170.0  225.0  1.0      0.0     146.0   1.0      2.8  1.0
# 293   67    1  2.0   152.0  212.0  0.0      0.0     150.0   0.0      0.8  1.0
# ...

# %%
#shape it used to shape of matrix
heart_7.shape
# Out:
# (303, 14)

# %%
#describe
heart_7.describe(include='all')
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  275.000000  260.000000  250.000000  260.000000
# mean    54.366337    0.683168    0.949091  133.042308  246.184000    0.157692
# std      9.082101    0.466011    1.034597   17.583396   49.364782    0.365155
# min     29.000000    0.000000    0.000000  100.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  212.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  241.500000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  275.750000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  417.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  260.000000  293.000000  281.000000  275.000000  253.000000  253.000000
# mean     0.519231  149.412969    0.338078    1.081455    1.383399    0.719368
# ...

# %%
#coulumns it use for how many columns and coluumn names
heart_7.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
#count it use for each column how many data is available given dataset
heart_7.count()
# Out:
# age         303
# sex         303
# cp          275
# trtbps      260
# chol        250
# fbs         260
# restecg     260
# thalachh    293
# exng        281
# oldpeak     275
# slp         253
# caa         253
# thall       265
# output      303
# dtype: int64

# %%
#value_counts specific(sex) It counts occurrences of unique values in a pandas Series.
heart_7.sex.value_counts()
# Out:
# sex
# 1    207
# 0     96
# Name: count, dtype: int64

# %%
#values counts showing pie chart
plt.pie(heart_7.sex.value_counts(),autopct='%1.3f%%',labels=['Male','Female'])
plt.show()

# %%
heart_7.output.value_counts()
# Out:
# output
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
# histplot
sns.histplot(heart_7.output)
# Out:
# <Axes: xlabel='output', ylabel='Count'>

# %%
#isna or isnull it use for check null values given dataset
heart_7.isna().sum()
# Out:
# age          0
# sex          0
# cp          28
# trtbps      43
# chol        53
# fbs         43
# restecg     43
# thalachh    10
# exng        22
# oldpeak     28
# slp         50
# caa         50
# thall       38
# output       0
# dtype: int64

# %% [markdown]
# # **Checking Null Values**

# %%
#null shows using matrix
msno.matrix(heart_7)
# Out:
# <Axes: >

# %%
#showing null values using heatmap
sns.heatmap(heart_7.isnull())
# Out:
# <Axes: >

# %%
#copy is use for dataset copied into another variable
heart = heart_7.copy()
heart
# Out:
#      age  sex   cp  trtbps   chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1  3.0   145.0  233.0  1.0      0.0     150.0   0.0      2.3  0.0
# 1     37    1  2.0   130.0  250.0  0.0      1.0     187.0   0.0      3.5  0.0
# 2     41    0  1.0   130.0  204.0  0.0      0.0     172.0   0.0      1.4  2.0
# 3     56    1  1.0   120.0  236.0  0.0      1.0     178.0   0.0      0.8  2.0
# 4     57    0  0.0   120.0  354.0  0.0      1.0     163.0   1.0      0.6  2.0
# ..   ...  ...  ...     ...    ...  ...      ...       ...   ...      ...  ...
# 298   57    0  0.0   140.0  241.0  0.0      1.0     123.0   1.0      0.2  1.0
# 299   45    1  3.0   110.0  264.0  0.0      1.0     132.0   0.0      1.2  1.0
# 300   68    1  0.0   144.0  193.0  1.0      1.0     141.0   0.0      3.4  1.0
# 301   57    1  0.0   130.0  131.0  0.0      1.0     115.0   1.0      1.2  1.0
# 302   57    0  1.0   130.0  236.0  0.0      0.0     174.0   0.0      0.0  1.0
#
#      caa  thall  output
# ...

# %% [markdown]
# # **Filling Null Values**

# %%
#filling column cp male group in male based on age and sex
heart =heart_7.loc[(heart_7.sex == 1), 'cp'] = heart_7.loc[(heart_7.sex == 1), 'cp'].fillna(0)
#filling column cp female group age < 50 based on age and sex
heart =heart_7.loc[(heart_7.sex == 0) & (heart_7.age < 50), 'cp'] = heart_7.loc[(heart_7.sex == 0) & (heart_7.age < 50), 'cp'].fillna(2)
#filling column cp female group age >= 50 based on age and
heart =heart_7.loc[(heart_7.sex == 0) & (heart_7.age >= 50), 'cp'] = heart_7.loc[(heart_7.sex == 0) & (heart_7.age >= 50), 'cp'].fillna(0)
heart_7.isna().sum()
heart_7
# Out:
#      age  sex   cp  trtbps   chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1  3.0   145.0  233.0  1.0      0.0     150.0   0.0      2.3  0.0
# 1     37    1  2.0   130.0  250.0  0.0      1.0     187.0   0.0      3.5  0.0
# 2     41    0  1.0   130.0  204.0  0.0      0.0     172.0   0.0      1.4  2.0
# 3     56    1  1.0   120.0  236.0  0.0      1.0     178.0   0.0      0.8  2.0
# 4     57    0  0.0   120.0  354.0  0.0      1.0     163.0   1.0      0.6  2.0
# ..   ...  ...  ...     ...    ...  ...      ...       ...   ...      ...  ...
# 298   57    0  0.0   140.0  241.0  0.0      1.0     123.0   1.0      0.2  1.0
# 299   45    1  3.0   110.0  264.0  0.0      1.0     132.0   0.0      1.2  1.0
# 300   68    1  0.0   144.0  193.0  1.0      1.0     141.0   0.0      3.4  1.0
# 301   57    1  0.0   130.0  131.0  0.0      1.0     115.0   1.0      1.2  1.0
# 302   57    0  1.0   130.0  236.0  0.0      0.0     174.0   0.0      0.0  1.0
#
#      caa  thall  output
# ...

# %%
#filling missing trtbps based on mode value
heart = heart_7['trtbps'] = heart_7['trtbps'].fillna(heart_7['trtbps'].mode()[0])
heart_7.isna().sum()
# Out:
# age          0
# sex          0
# cp           0
# trtbps       0
# chol        53
# fbs         43
# restecg     43
# thalachh    10
# exng        22
# oldpeak     28
# slp         50
# caa         50
# thall       38
# output       0
# dtype: int64

# %%
#filling chol missing values based on median
heart = heart_7['chol'] = heart_7['chol'].fillna(heart_7['chol'].median())
#heart_7

# %%
#filling fbs missing values based on mode
heart = heart_7['fbs'] = heart_7['fbs'].fillna(heart_7['fbs'].mode()[0])
#heart_7

# %%
#filling resctecg female missing values based on mode
heart = heart_7.loc[(heart_7.sex == 0), 'restecg'] = heart_7.loc[(heart_7.sex == 0), 'restecg'].fillna(1.0)
#filling resctecg female missing values based on mode
heart = heart_7.loc[(heart_7.sex == 1), 'restecg'] = heart_7.loc[(heart_7.sex == 1), 'restecg'].fillna(0.0)
heart_7
# Out:
#      age  sex   cp  trtbps   chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1  3.0   145.0  233.0  1.0      0.0     150.0   0.0      2.3  0.0
# 1     37    1  2.0   130.0  250.0  0.0      1.0     187.0   0.0      3.5  0.0
# 2     41    0  1.0   130.0  204.0  0.0      0.0     172.0   0.0      1.4  2.0
# 3     56    1  1.0   120.0  236.0  0.0      1.0     178.0   0.0      0.8  2.0
# 4     57    0  0.0   120.0  354.0  0.0      1.0     163.0   1.0      0.6  2.0
# ..   ...  ...  ...     ...    ...  ...      ...       ...   ...      ...  ...
# 298   57    0  0.0   140.0  241.0  0.0      1.0     123.0   1.0      0.2  1.0
# 299   45    1  3.0   110.0  264.0  0.0      1.0     132.0   0.0      1.2  1.0
# 300   68    1  0.0   144.0  193.0  1.0      1.0     141.0   0.0      3.4  1.0
# 301   57    1  0.0   130.0  131.0  0.0      1.0     115.0   1.0      1.2  1.0
# 302   57    0  1.0   130.0  236.0  0.0      0.0     174.0   0.0      0.0  1.0
#
#      caa  thall  output
# ...

# %%
#filling thalachh missing values based on median
heart = heart_7['thalachh'] = heart_7['thalachh'].fillna(heart_7['thalachh'].median())
#heart_7

# %%
#filling exng missing values based on mode
heart = heart_7['exng'] = heart_7['exng'].fillna(heart_7['exng'].mode()[0])
#heart_7

# %%
#filling oldpeak female missing values based on mean()
heart = heart_7.loc[(heart_7.sex == 0), 'oldpeak'] = heart_7.loc[(heart_7.sex == 0), 'oldpeak'].fillna(0.92)
#filling oldpeak male missing values based on mean()
heart = heart_7.loc[(heart_7.sex == 1), 'oldpeak'] = heart_7.loc[(heart_7.sex == 1), 'oldpeak'].fillna(1.14)
#heart_7

# %%
#filling slp female missing values based on medain value
heart = heart_7.loc[(heart_7.sex == 0), 'slp'] = heart_7.loc[(heart_7.sex == 0), 'slp'].fillna(2.0)
#filling slp male missign values based on meadian value
heart = heart_7.loc[(heart_7.sex == 1), 'slp'] = heart_7.loc[(heart_7.sex == 1), 'slp'].fillna(1.0)
#heart_7

# %%
#filling caa female missing values based on mean()
heart = heart_7.loc[(heart_7.sex == 0), 'caa'] = heart_7.loc[(heart_7.sex == 0), 'caa'].fillna(0.0)
#filling caa male missing values based on mean()
heart = heart_7.loc[(heart_7.sex == 1), 'caa'] = heart_7.loc[(heart_7.sex == 1), 'caa'].fillna(1.0)
heart_7
# Out:
#      age  sex   cp  trtbps   chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1  3.0   145.0  233.0  1.0      0.0     150.0   0.0      2.3  0.0
# 1     37    1  2.0   130.0  250.0  0.0      1.0     187.0   0.0      3.5  0.0
# 2     41    0  1.0   130.0  204.0  0.0      0.0     172.0   0.0      1.4  2.0
# 3     56    1  1.0   120.0  236.0  0.0      1.0     178.0   0.0      0.8  2.0
# 4     57    0  0.0   120.0  354.0  0.0      1.0     163.0   1.0      0.6  2.0
# ..   ...  ...  ...     ...    ...  ...      ...       ...   ...      ...  ...
# 298   57    0  0.0   140.0  241.0  0.0      1.0     123.0   1.0      0.2  1.0
# 299   45    1  3.0   110.0  264.0  0.0      1.0     132.0   0.0      1.2  1.0
# 300   68    1  0.0   144.0  193.0  1.0      1.0     141.0   0.0      3.4  1.0
# 301   57    1  0.0   130.0  131.0  0.0      1.0     115.0   1.0      1.2  1.0
# 302   57    0  1.0   130.0  236.0  0.0      0.0     174.0   0.0      0.0  1.0
#
#      caa  thall  output
# ...

# %%
#filling thall female missing values based on mode()
heart = heart_7.loc[(heart_7.sex == 0), 'thall'] = heart_7.loc[(heart_7.sex == 0), 'thall'].fillna(2.0)
#filling thall male missing values based on mode()
heart = heart_7.loc[(heart_7.sex == 1), 'thall'] = heart_7.loc[(heart_7.sex == 1), 'thall'].fillna(3.0)
heart_7
# Out:
#      age  sex   cp  trtbps   chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1  3.0   145.0  233.0  1.0      0.0     150.0   0.0      2.3  0.0
# 1     37    1  2.0   130.0  250.0  0.0      1.0     187.0   0.0      3.5  0.0
# 2     41    0  1.0   130.0  204.0  0.0      0.0     172.0   0.0      1.4  2.0
# 3     56    1  1.0   120.0  236.0  0.0      1.0     178.0   0.0      0.8  2.0
# 4     57    0  0.0   120.0  354.0  0.0      1.0     163.0   1.0      0.6  2.0
# ..   ...  ...  ...     ...    ...  ...      ...       ...   ...      ...  ...
# 298   57    0  0.0   140.0  241.0  0.0      1.0     123.0   1.0      0.2  1.0
# 299   45    1  3.0   110.0  264.0  0.0      1.0     132.0   0.0      1.2  1.0
# 300   68    1  0.0   144.0  193.0  1.0      1.0     141.0   0.0      3.4  1.0
# 301   57    1  0.0   130.0  131.0  0.0      1.0     115.0   1.0      1.2  1.0
# 302   57    0  1.0   130.0  236.0  0.0      0.0     174.0   0.0      0.0  1.0
#
#      caa  thall  output
# ...

# %%
heart_7.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %% [markdown]
# # **After Filling Null Values, the Dataset Visualization**

# %%
#After fillied null values dataset with matrix
msno.matrix(heart_7)
# Out:
# <Axes: >

# %% [markdown]
# ## Descriptive Statastics

# %%
#After filled null values dataset with heatmap
sns.heatmap(heart_7.isnull())
# Out:
# <Axes: >

# %%
#describe() is used to generate descriptive statistics of a dataset. In short,
#it summarizes the central tendency, dispersion, and shape of a dataset's distribution
summary= heart_7.describe(include='all')
summary
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.894389  131.191419  245.364686    0.135314
# std      9.082101    0.466011    1.027149   16.909664   44.859713    0.342624
# min     29.000000    0.000000    0.000000  100.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  219.000000    0.000000
# 50%     55.000000    1.000000    0.000000  130.000000  241.500000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  269.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  417.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.504950  149.498350    0.313531    1.075974    1.389439    0.696370
# ...

# %%
#Featrue columns checking value_counts()
categorical_cols = ["sex", "cp", "fbs", "restecg", "exng", "slp", "caa", "thall", "output"]
frequency_tables = {}
for col in categorical_cols:
  frequency_tables[col] = heart_7[col].value_counts()

print(frequency_tables)
# Out:
# {'sex': sex
# 1    207
# 0     96
# Name: count, dtype: int64, 'cp': cp
# 0.0    157
# 2.0     85
# 1.0     41
# 3.0     20
# Name: count, dtype: int64, 'fbs': fbs
# 0.0    262
# 1.0     41
# Name: count, dtype: int64, 'restecg': restecg
# 0.0    154
# 1.0    145
# 2.0      4
# Name: count, dtype: int64, 'exng': exng
# 0.0    208
# 1.0     95
# Name: count, dtype: int64, 'slp': slp
# 1.0    151
# 2.0    135
# 0.0     17
# Name: count, dtype: int64, 'caa': caa
# 0.0    165
# 1.0     86
# 2.0     33
# 3.0     17
# 4.0      2
# Name: count, dtype: int64, 'thall': thall
# 2.0    155
# 3.0    128
# 1.0     18
# 0.0      2
# Name: count, dtype: int64, 'output': output
# 1    165
# 0    138
# Name: count, dtype: int64}

# %%
# I Want change into sex and cp numeric datatype to categorical datatype
heart_7['sex'] = heart_7['sex'].replace({1: 'Male', 0: 'Female'})
heart_7['cp'] = heart_7['cp'].replace({0: 'typical angina', 1: 'atypical angina', 2: 'non-anginal pain', 3: 'asymptomatic'})
heart_7
# Out:
#      age     sex                cp  trtbps   chol  fbs  restecg  thalachh  \
# 0     63    Male      asymptomatic   145.0  233.0  1.0      0.0     150.0
# 1     37    Male  non-anginal pain   130.0  250.0  0.0      1.0     187.0
# 2     41  Female   atypical angina   130.0  204.0  0.0      0.0     172.0
# 3     56    Male   atypical angina   120.0  236.0  0.0      1.0     178.0
# 4     57  Female    typical angina   120.0  354.0  0.0      1.0     163.0
# ..   ...     ...               ...     ...    ...  ...      ...       ...
# 298   57  Female    typical angina   140.0  241.0  0.0      1.0     123.0
# 299   45    Male      asymptomatic   110.0  264.0  0.0      1.0     132.0
# 300   68    Male    typical angina   144.0  193.0  1.0      1.0     141.0
# 301   57    Male    typical angina   130.0  131.0  0.0      1.0     115.0
# 302   57  Female   atypical angina   130.0  236.0  0.0      0.0     174.0
#
#      exng  oldpeak  slp  caa  thall  output
# ...

# %%
# I want change rename to all column names
cols = ['age', 'sex', 'chest_pain', 'resting_bp', 'cholesterol_level',
                           ' fasting_blood_sugar_level', 'Resting_electrocardiographic_results',
                           'heart_rate_during_exercise_stress', 'exercise_induced_angina',
                           ' exercise_stress_testing', 'slope', 'caa', 'thallium_stress_test', 'output']
heart_7.columns = cols
heart_7
# Out:
#      age     sex        chest_pain  resting_bp  cholesterol_level  \
# 0     63    Male      asymptomatic       145.0              233.0
# 1     37    Male  non-anginal pain       130.0              250.0
# 2     41  Female   atypical angina       130.0              204.0
# 3     56    Male   atypical angina       120.0              236.0
# 4     57  Female    typical angina       120.0              354.0
# ..   ...     ...               ...         ...                ...
# 298   57  Female    typical angina       140.0              241.0
# 299   45    Male      asymptomatic       110.0              264.0
# 300   68    Male    typical angina       144.0              193.0
# 301   57    Male    typical angina       130.0              131.0
# 302   57  Female   atypical angina       130.0              236.0
#
#       fasting_blood_sugar_level  Resting_electrocardiographic_results  \
# 0                           1.0                                   0.0
# ...

# %%
#Using BarPlot Distribution of sex and output(Target Column)
import matplotlib.pyplot as plt

# Count the occurrences of each combination of 'sex' and 'output'
counts = heart_7[['sex','output']].value_counts()

# Plot the counts as a bar chart
counts.plot(kind='bar')
plt.xlabel("(Sex, Output)")
plt.ylabel("Count")
plt.title("Distribution of Sex and Output")
plt.show()

# %%
#Combinations of Sex and Chest_pain(cp)
import matplotlib.pyplot as plt

# Count the values for combinations of 'sex', 'cp', and 'output'
value_counts = heart_7[['output']].value_counts()

# Plot the value counts using a histogram
sns.distplot(value_counts)  #Use plt.hist for a histogram

plt.show()

# %%
#using Violinplot Chest_pain(cp) column
import matplotlib.pyplot as plt
import seaborn as sns

sns.violinplot(x='chest_pain', data=heart_7)
plt.xticks(rotation=40) # Rotate x-axis labels instead
plt.show()

# %%
#Using swarmplot resting_bp and output(target_column)
sns.swarmplot(x='output', y='resting_bp', data=heart_7)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Example DataFrame (replace with your actual DataFrame)
# df = pd.read_csv('your_data.csv')

# Columns and target column
columns = [
    'chest_pain_encoded',
    'cholesterol_level',
    'heart_rate_during_exercise_stress',
    'exercise_induced_angina',
    'slope',
    'caa'
]
target_column = 'output'  # Replace with your actual target column name

# Create subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20, 12))

for i, column in enumerate(columns):
    row = i // 3
    col = i % 3
    # Check if the column exists in your DataFrame before plotting
    if column in heart_7.columns:
        sns.boxplot(x=column, hue=target_column, data=heart_7, ax=axes[row, col])
        axes[row, col].set_title(f'{column} vs {target_column}')
    else:
        print(f"Warning: Column '{column}' not found in DataFrame.")

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Label Encoding**

# %%
#Using Label Encoding Categorical columns into numberic columns
#Initialize LabelEncoder
#encoding the values inthe sex and chest pain columns
import pandas as pd
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

# Encode 'sex' column and replace the original
heart_7['sex_encoded'] = label_encoder.fit_transform(heart_7['sex'])

# Encode 'chest_pain' column and replace the original
heart_7['chest_pain_encoded'] = label_encoder.fit_transform(heart_7['chest_pain'])

# Keep only the transformed columns
heart_7_encoded = heart_7[['age','sex_encoded', 'chest_pain_encoded','resting_bp', 'cholesterol_level',
       ' fasting_blood_sugar_level', 'Resting_electrocardiographic_results',
       'heart_rate_during_exercise_stress', 'exercise_induced_angina',
       ' exercise_stress_testing', 'slope', 'caa', 'thallium_stress_test' ,'output']]

# Print the updated dataframe to check the changes
#print(heart_7_encoded.head())

# %%
#Encoded
heart_7_encoded
# Out:
#      age  sex_encoded  chest_pain_encoded  resting_bp  cholesterol_level  \
# 0     63            1                   0       145.0              233.0
# 1     37            1                   2       130.0              250.0
# 2     41            0                   1       130.0              204.0
# 3     56            1                   1       120.0              236.0
# 4     57            0                   3       120.0              354.0
# ..   ...          ...                 ...         ...                ...
# 298   57            0                   3       140.0              241.0
# 299   45            1                   0       110.0              264.0
# 300   68            1                   3       144.0              193.0
# 301   57            1                   3       130.0              131.0
# 302   57            0                   1       130.0              236.0
#
#       fasting_blood_sugar_level  Resting_electrocardiographic_results  \
# ...

# %%
#Encoded Column Names
print(heart_7_encoded.columns)
# Out:
# Index(['age', 'sex_encoded', 'chest_pain_encoded', 'resting_bp',
#        'cholesterol_level', ' fasting_blood_sugar_level',
#        'Resting_electrocardiographic_results',
#        'heart_rate_during_exercise_stress', 'exercise_induced_angina',
#        ' exercise_stress_testing', 'slope', 'caa', 'thallium_stress_test',
#        'output'],
#       dtype='object')

# %%
#Target Column Stored into another Variable
X = heart_7_encoded.drop('output', axis=1)  # Features (all columns except 'output')
y = heart_7_encoded['output']  # Target variable

# %% [markdown]
# # **Logistic Regression**

# %%
#split the dataset into 70%  Training and 30 % test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=3)

# %%
#using simple logistic regression
from sklearn.linear_model import LogisticRegression

# Initialize the logistic regression model
model = LogisticRegression(max_iter=50)  # Increase max_iter if needed for convergence

# Fit the model on the training data
# Fit the model
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=50)

# %%
# Assuming you already have your model fitted as 'model' and X_test, y_test defined

# Predict on the test set
y_pred = model.predict(X_test)

# Evaluate the model
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix # Import confusion_matrix

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')

print(classification_report(y_test, y_pred))

conf_matrix = confusion_matrix(y_test, y_pred) # Use confusion_matrix directly
#print('Confusion Matrix:')
#print(conf_matrix)


#Assuming 'conf_matrix' is already calculated
#using heatmap Predicated values and Actual
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues') # Changed 'palette' to 'cmap'
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Heatmap Logistic Regression')
plt.show()
# Out:
# Accuracy: 0.82
#               precision    recall  f1-score   support
#
#            0       0.87      0.68      0.76        38
#            1       0.80      0.92      0.86        53
#
#     accuracy                           0.82        91
#    macro avg       0.83      0.80      0.81        91
# weighted avg       0.83      0.82      0.82        91

# %%
# Predict probabilities for ROC curve
y_prob = model.predict_proba(X_test)[:, 1]

# Plot ROC curve
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Logstic Regression (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
#accuracy of precdicted values and Trained values
x_pred = model.predict(X_train)
train_acc = accuracy_score(y_train, x_pred)
print(train_acc)
# Out:
# 0.8207547169811321

# %% [markdown]
# ##**Random** **Forest**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Assuming X_train, X_test, y_train, y_test are already defined
model = RandomForestClassifier(n_estimators=10, criterion='gini', max_features='sqrt', random_state=1, min_samples_leaf=10)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)  # Testing and Predicting the values

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')

print(classification_report(y_test, y_pred))

conf_matrix = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Accuracy: 0.75
#               precision    recall  f1-score   support
#
#            0       0.71      0.66      0.68        38
#            1       0.77      0.81      0.79        53
#
#     accuracy                           0.75        91
#    macro avg       0.74      0.73      0.74        91
# weighted avg       0.75      0.75      0.75        91

# %%
# ROC Curve
import numpy as np
from scipy import interp

# Predict probabilities for ROC curve
y_prob = model.predict_proba(X_test)[:, 1]

# Plot ROC curve
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)

# Interpolating the ROC curve to smooth it
fpr_new = np.linspace(0, 1, 100)
tpr_smooth = interp(fpr_new, fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr_new, tpr_smooth, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Random Forest (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
#accuracy of precdicted values and Trained values
x_pred = model.predict(X_train)
train_acc = accuracy_score(y_train, x_pred)
print(train_acc)
# Out:
# 0.8349056603773585

# %% [markdown]
# # **Decession Tree**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import tree
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Assuming X_train, X_test, y_train, y_test are already defined
model = tree.DecisionTreeClassifier(criterion='gini', max_depth=5, min_samples_split=23, random_state=15)
model.fit(X_train, y_train)

# Calculate accuracy on the test set
accuracy = model.score(X_test, y_test)
print(f'Accuracy on test set: {accuracy:.2f}')

# Calculate accuracy on the training set (optional)
train_accuracy = model.score(X_train, y_train)
print(f'Accuracy on training set: {train_accuracy:.2f}')

# Predict the test set results
y_pred = model.predict(X_test)

# Generate the classification report
print(classification_report(y_test, y_pred))

# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Accuracy on test set: 0.81
# Accuracy on training set: 0.83
#               precision    recall  f1-score   support
#
#            0       0.80      0.74      0.77        38
#            1       0.82      0.87      0.84        53
#
#     accuracy                           0.81        91
#    macro avg       0.81      0.80      0.81        91
# weighted avg       0.81      0.81      0.81        91

# %%
# ROC Curve
import numpy as np
from scipy import interp

# Predict probabilities for ROC curve
y_prob = model.predict_proba(X_test)[:, 1]

# Plot ROC curve
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)

# Interpolating the ROC curve to smooth it
fpr_new = np.linspace(0, 1, 100)
tpr_smooth = interp(fpr_new, fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr_new, tpr_smooth, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Decession Tree (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
#accuracy of precdicted values and Trained values
x_pred = model.predict(X_train)
train_acc = accuracy_score(y_train, x_pred)
print(train_acc)
# Out:
# 0.8301886792452831

# %% [markdown]
# # **Support Vector Machine**

# %%
# Step 1: Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Step 2: Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=8)

# Step 3: Initialize and train the SVM classifier
clf = SVC(kernel='linear')
clf.fit(X_train, y_train)

# Step 4: Predict on the test set and compute accuracy
y_pred = clf.predict(X_test)

# Compute accuracy score
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')

# Generate the classification report
print(classification_report(y_test, y_pred))

# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Accuracy: 0.82
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79        38
#            1       0.85      0.85      0.85        53
#
#     accuracy                           0.82        91
#    macro avg       0.82      0.82      0.82        91
# weighted avg       0.82      0.82      0.82        91

# %%
# ROC Curve
import numpy as np
from scipy import interp

# Predict probabilities for ROC curve
y_prob = model.predict_proba(X_test)[:, 1]

# Plot ROC curve
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)

# Interpolating the ROC curve to smooth it
fpr_new = np.linspace(0, 1, 100)
tpr_smooth = interp(fpr_new, fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr_new, tpr_smooth, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Support Vector Machine (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
#accuracy of precdicted values and Trained values
x_pred = model.predict(X_train)
train_acc = accuracy_score(y_train, x_pred)
print(train_acc)
# Out:
# 0.8207547169811321

# %% [markdown]
# # **Feature Selecting**

# %%
from sklearn.feature_selection import SelectFromModel

# Fit the Random Forest classifier
model.fit(X_train, y_train)

# Use SelectFromModel to select features based on importance weights
selector = SelectFromModel(model , threshold="mean", prefit=True)
X_train_selected = selector.transform(X_train)
X_test_selected = selector.transform(X_test)

# Train a new Random Forest classifier on the selected features
rf_classifier_selected = RandomForestClassifier(n_estimators=10, random_state=42)
rf_classifier_selected.fit(X_train_selected, y_train)

# Make predictions and evaluate the model
y_pred_selected = rf_classifier_selected.predict(X_test_selected)
accuracy_selected = accuracy_score(y_test, y_pred_selected)
classification_rep_selected = classification_report(y_test, y_pred_selected)

# Get the selected feature names
selected_features = X.columns[selector.get_support()]

accuracy_selected, classification_rep_selected, selected_features.tolist()
# Out:
# (0.7582417582417582,
#  '              precision    recall  f1-score   support\n\n           0       0.67      0.82      0.74        38\n           1       0.84      0.72      0.78        53\n\n    accuracy                           0.76        91\n   macro avg       0.76      0.77      0.76        91\nweighted avg       0.77      0.76      0.76        91\n',
#  ['chest_pain_encoded',
#   ' exercise_stress_testing',
#   'caa',
#   'thallium_stress_test'])

# %% [markdown]
# # **AdaBoost Classifier**

# %%
from sklearn.ensemble import AdaBoostClassifier

# Train AdaBoost model
ada_model = AdaBoostClassifier(n_estimators=10, random_state=10)
ada_model.fit(X_train, y_train)

# Predictions
y_pred_ada = ada_model.predict(X_test)

# Evaluate the model
accuracy_ada = accuracy_score(y_test, y_pred_ada)
report_ada = classification_report(y_test, y_pred_ada)

accuracy_ada, report_ada
# Out:
# (0.8021978021978022,
#  '              precision    recall  f1-score   support\n\n           0       0.73      0.84      0.78        38\n           1       0.87      0.77      0.82        53\n\n    accuracy                           0.80        91\n   macro avg       0.80      0.81      0.80        91\nweighted avg       0.81      0.80      0.80        91\n')

# %% [markdown]
# # **Gradient Boosting Classifier**

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Train GradientBoostingClassifier model
ada_model = GradientBoostingClassifier(n_estimators=15, random_state=1)
ada_model.fit(X_train, y_train)

# Predictions
y_pred_ada = ada_model.predict(X_test)

# Evaluate the model
accuracy_ada = accuracy_score(y_test, y_pred_ada)
report_ada = classification_report(y_test, y_pred_ada)

accuracy_ada, report_ada
# Out:
# (0.8571428571428571,
#  '              precision    recall  f1-score   support\n\n           0       0.82      0.84      0.83        38\n           1       0.88      0.87      0.88        53\n\n    accuracy                           0.86        91\n   macro avg       0.85      0.86      0.85        91\nweighted avg       0.86      0.86      0.86        91\n')

# %% [markdown]
# # **XGB Classifier**

# %%
from xgboost import XGBClassifier

# Train  XGBoost model
ada_model = XGBClassifier(n_estimators=15, random_state=1) # Use XGBClassifier
ada_model.fit(X_train, y_train)

# Predictions
y_pred_ada = ada_model.predict(X_test)

# Evaluate the model
accuracy_ada = accuracy_score(y_test, y_pred_ada)
report_ada = classification_report(y_test, y_pred_ada)

accuracy_ada, report_ada
# Out:
# (0.8021978021978022,
#  '              precision    recall  f1-score   support\n\n           0       0.74      0.82      0.78        38\n           1       0.86      0.79      0.82        53\n\n    accuracy                           0.80        91\n   macro avg       0.80      0.80      0.80        91\nweighted avg       0.81      0.80      0.80        91\n')

# %%
#Feature Selecting columns showing with viloinplot
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Example DataFrame (replace with your actual DataFrame)
# df = pd.read_csv('your_data.csv')

# Columns and target column
columns = [
    'chest_pain_encoded',
    'cholesterol_level',
    'heart_rate_during_exercise_stress',
    'exercise_induced_angina',
    'slope',
    'caa'
]
target_column = 'output'  # Replace with your actual target column name

# Create subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20, 12))

for i, column in enumerate(columns):
    row = i // 3
    col = i % 3
    # Check if the column exists in your DataFrame before plotting
    if column in heart_7.columns:
        ax = axes[row, col]
        # Create a bar plot
        sns.violinplot(x=column, hue=target_column, data=heart_7, ax=ax)
        ax.set_title(f'{column} vs {target_column}')
    else:
        print(f"Warning: Column '{column}' not found in DataFrame.")

# Adjust layout
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Example DataFrame (replace with your actual DataFrame)
# df = pd.read_csv('your_data.csv')

# Columns and target column
columns = [

    'chest_pain_encoded',
    'cholesterol_level',
    'exercise_induced_angina',
   ' exercise_stress_testing',
    'caa'
]
target_column = 'output'  # Replace with your actual target column name

# Create subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20, 12))

for i, column in enumerate(columns):
    row = i // 3
    col = i % 3
    # Check if the column exists in your DataFrame before plotting
    if column in heart_7.columns:
        ax = axes[row, col]
        # Check if the column is numeric before creating a regression plot
        if pd.api.types.is_numeric_dtype(heart_7[column]):
            # Create a regression plot
            # Use 'scatter_kws' to control marker size
            sns.regplot(x=column, y=target_column, data=heart_7, ax=ax, scatter_kws={'s': 10})
            ax.set_title(f'{column} vs {target_column}')
        else:
            print(f"Warning: Column '{column}' is not numeric, skipping regression plot.")
    else:
        print(f"Warning: Column '{column}' not found in DataFrame.")

# Remove the empty subplot
fig.delaxes(axes[1, 2])

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# *  The dataset includes features such as age, sex, chest pain type, resting blood pressure, cholesterol, fasting blood sugar, resting electrocardiographic results, maximum heart rate achieved, exercise-induced angina, oldpeak, slope of the peak exercise ST segment, number of major vessels, thalassemia, and the target variable indicating heart disease presence.
#
#
# *   The objective is to predict heart disease.
#
#
#
# *  maximum heart rate achieved, exercise-induced angina, oldpeak, slope of the peak exercise ST segment, number of major vessels, thalassemia, and the target variable indicating heart disease presence. The objective is to predict heart disease.
#
# *  Initial EDA involves analyzing descriptive statistics, correlations, and visualizing data with histograms, Violinplots, barplots, and heatmaps.
#
# *  Data preprocessing includes handling missing values, scaling continuous features, and encoding categorical variables.
#
# *  For model building, the dataset is split into training and testing sets, and various algorithms such as Logistic Regression, Decision Trees, Random Forest, SVM and GBM are evaluated using metrics like accuracy and ROC-AUC.
# Model tuning involves hyperparameter optimization and cross-validation.
#
# *  The final model's feature importance is interpreted using SHAP values.
# *  Conclusions highlight key predictors and provide recommendations for healthcare professionals.
#
#
# *  Recommendations emphasize monitoring and managing significant predictors like age, cholesterol levels, and maximum heart rate achieved.
#
#
# *  Future work suggests improving the model with more data and advanced techniques like deep learning.
